# %%
# Import relevant libraries
import numpy as np
import gymnasium as gym
from gymnasium import spaces

import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas

# %%
# Warehouse simulator with a moving agent
class WarehouseEnv(gym.Env):
    """
    A warehouse environment conforming to the modern Gymnasium API.
    """
    
    # Add metadata, which is standard practice in Gymnasium
    metadata = {"render_modes": ["rgb_array", "human"], "render_fps": 4}

    def __init__(self, grid_size=5, num_items=5, max_steps=100, render_mode=None):
        super().__init__()

        self.grid_size = grid_size
        self.num_items = num_items
        self.max_steps = max_steps
        self.agent_pos = [0, 0]
        self.agent_carries_item = 0
        self.steps_taken = 0
        self.warehouse = np.zeros((grid_size, grid_size), dtype=int)
        self.item_locations = {}
        self.item_demand = np.random.randint(1, 10, size=num_items + 1)
        self.item_demand[0] = 0
        
        # Store the render_mode and assert it's valid
        assert render_mode is None or render_mode in self.metadata["render_modes"]
        self.render_mode = render_mode

        self.action_space = spaces.Discrete(5)
        self.observation_space = spaces.Dict({
            "agent_pos": spaces.Box(low=0, high=grid_size - 1, shape=(2,), dtype=int),
            "agent_carries": spaces.Discrete(num_items + 1),
            "warehouse_layout": spaces.Box(low=0, high=num_items, shape=(grid_size, grid_size), dtype=int)
        })

    def _get_obs(self):
        return {
            "agent_pos": np.array(self.agent_pos),
            "agent_carries": self.agent_carries_item,
            "warehouse_layout": self.warehouse
        }

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.agent_pos = [0, 0]
        self.agent_carries_item = 0
        self.steps_taken = 0
        self.warehouse.fill(0)
        self.item_locations.clear()

        for item in range(1, self.num_items + 1):
            while True:
                row, col = self.np_random.integers(0, self.grid_size, size=2)
                if self.warehouse[row, col] == 0:
                    self.warehouse[row, col] = item
                    self.item_locations[item] = (row, col)
                    break
        obs = self._get_obs()
        return obs, {}

    def step(self, action):
        self.steps_taken += 1
        reward = -0.01

        if action < 4:
            new_pos = self.agent_pos.copy()
            if action == 0: new_pos[0] -= 1
            elif action == 1: new_pos[0] += 1
            elif action == 2: new_pos[1] -= 1
            elif action == 3: new_pos[1] += 1
            if 0 <= new_pos[0] < self.grid_size and 0 <= new_pos[1] < self.grid_size:
                self.agent_pos = new_pos
            else:
                reward -= 0.1
        elif action == 4:
            agent_r, agent_c = self.agent_pos
            if self.agent_carries_item > 0:
                if self.warehouse[agent_r, agent_c] == 0:
                    item_id = self.agent_carries_item
                    self.warehouse[agent_r, agent_c] = item_id
                    self.item_locations[item_id] = (agent_r, agent_c)
                    self.agent_carries_item = 0
                    distance = agent_r + agent_c
                    reward += self.item_demand[item_id] / (distance + 1) * 5
                else:
                    reward -= 0.2
            else:
                item_on_floor = self.warehouse[agent_r, agent_c]
                if item_on_floor > 0:
                    self.agent_carries_item = item_on_floor
                    self.warehouse[agent_r, agent_c] = 0
                    del self.item_locations[item_on_floor]
                    reward += 0.1
                else:
                    reward -= 0.2

        terminated = self.steps_taken >= self.max_steps
        truncated = False
        obs = self._get_obs()
        return obs, reward, terminated, truncated, {}

    
    def render(self):
        """ Render the environment with a legend for each color.
            - Red: Agent
            - Yellow: Agent carrying an item
            - Viridis colors: Items on the floor
            - White: Empty spaces"""
        
        if self.render_mode == "rgb_array":
            fig, ax = plt.subplots(figsize=(7,7))
            render_grid = np.copy(self.warehouse)
            agent_r, agent_c = self.agent_pos

            agent_render_value = self.num_items + 2
            if self.agent_carries_item > 0:
                agent_render_value += 1

            render_grid[agent_r, agent_c] = agent_render_value

            cmap_colors = [(1, 1, 1, 1)]
            viridis = plt.colormaps.get('viridis')
            item_colors = viridis(np.linspace(0, 1, self.num_items))
            cmap_colors.extend(item_colors)
            cmap_colors.append((1, 0, 0, 1)) # agent = red
            cmap_colors.append((1, 1, 0, 1)) # agent carrying = yellow

            custom_map = colors.ListedColormap(cmap_colors)
            bounds = np.arange(self.num_items + 4) - 0.5
            norm = colors.BoundaryNorm(bounds, custom_map.N)

            ax.imshow(render_grid, cmap=custom_map, norm=norm)

            ax.set_xticks(np.arange(-0.5, self.grid_size, 1), minor=True)
            ax.set_yticks(np.arange(-0.5, self.grid_size, 1), minor=True)
            ax.grid(which="minor", color="black", linewidth=0.5)
            ax.tick_params(which="both", bottom=False, left=False, labelbottom=False, labelleft=False)

            for r in range(self.grid_size):
                for c in range(self.grid_size):
                    item_id = self.warehouse[r,c]
                    if item_id > 0:
                        ax.text(c, r, str(item_id), ha='center', va='center', color='white', weight='bold')
            
            from matplotlib.patches import Patch
            legend_elements = [
                Patch(facecolor='red', edgecolor='black', label='Agent (Empty)'),
                Patch(facecolor='yellow', edgecolor='black', label='Agent (Carrying)'),
                Patch(facecolor=viridis(0.5), edgecolor='black', label='Item'),
                Patch(facecolor='white', edgecolor='black', label='Empty Space')]

            ax.legend(handles=legend_elements, bbox_to_anchor=(0.5, -0.05), loc='upper center', ncol=2)
            plt.tight_layout(rect=[0, 0.05, 1, 1])

            canvas = FigureCanvas(fig)
            canvas.draw()
            width, height = fig.canvas.get_width_height()
            image = np.frombuffer(canvas.buffer_rgba(), dtype='uint8').reshape(height, width, 4)[:, :, :3]
            plt.close(fig)
            return image

# %%
import torch
import stable_baselines3
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback, BaseCallback
import imageio
import os
from gymnasium.wrappers import FlattenObservation

# Check PyTorch GPU availability
if torch.cuda.is_available():
    print("CUDA available, Stable Baselines3 will use GPU.")
    device = 'cuda'
else:
    print("CUDA not available, Stable Baselines3 will use CPU.")
    device = 'cpu'

# SaveAnimationCallback class (no changes needed here)
class SaveAnimationCallback(BaseCallback):
    def __init__(self, save_freq: int, output_path: str = './animation_frames/', verbose: int = 0):
        super(SaveAnimationCallback, self).__init__(verbose)
        self.save_freq = save_freq
        self.output_path = output_path
        os.makedirs(self.output_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.save_freq == 0:
            # self.training_env.render() is vectorized, so we access the underlying env
            img = self.training_env.get_images()[0]
            filename = os.path.join(self.output_path, f"frame_{self.num_timesteps:06d}.png")
            imageio.imwrite(filename, img)
        return True

# 1. Create the base environment
env = WarehouseEnv(render_mode="rgb_array")
# 2. Apply the FlattenObservation wrapper
env = FlattenObservation(env)
# 3. Wrap with Monitor for statistics
env = Monitor(env)
# 4. Vectorize the environment for Stable Baselines3
env = DummyVecEnv([lambda: env])
# ------------------------------------

# dqn_kwargs dictionary
dqn_kwargs = {
    "policy":"MlpPolicy",
    "env":env,
    "learning_rate": 5e-4, # Low learning rate for more stable learning
    "buffer_size": 50000,
    "learning_starts": 5000,
    "batch_size": 128,
    "gamma": 0.99,
    "train_freq": (4, "step"),
    "target_update_interval": 5000,
    "exploration_fraction": 0.2,
    "exploration_final_eps": 0.02,
    "verbose": 1,
    "tensorboard_log": "./logs/dqn_warehouse/",
    "device": device
}

model = DQN(**dqn_kwargs)

# Callbacks
checkpoint_callback = CheckpointCallback(save_freq=5000, save_path="./models/dqn/", name_prefix="warehouse_dqn")

eval_env = WarehouseEnv()
eval_env = FlattenObservation(eval_env) # Eval env also needs to be flattened
eval_env = DummyVecEnv([lambda: eval_env])
eval_callback = EvalCallback(eval_env, best_model_save_path="./models/dqn_best",
                             log_path="./logs/dqn_eval/", eval_freq=10000, deterministic=True)

animation_callback = SaveAnimationCallback(save_freq=5000)

# Learn
total_timesteps = 100000 # Increased more complex problem
model.learn(total_timesteps=total_timesteps, callback=[checkpoint_callback, eval_callback, animation_callback])

# Close environments
env.close()
eval_env.close()

model.save("./models/dqn_warehouse_final")
print("Training Complete. Model saved successfully.")
# Out:
# CUDA available, Stable Baselines3 will use GPU.
# Using cuda device
# Logging to ./logs/dqn_warehouse/DQN_3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3901     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 400      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 40.2     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4477     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 32.7     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4653     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4631     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 29.5     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4814     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4925     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4827     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 26.6     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4915     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 24.6     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4983     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5053     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5106     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5158     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 715      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5200     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0207   |
# |    n_updates        | 49       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 687      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.193    |
# |    n_updates        | 149      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.706    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 667      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 6000     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.157    |
# |    n_updates        | 249      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 650      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.235    |
# |    n_updates        | 349      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 633      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6800     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.035    |
# |    n_updates        | 449      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.647    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 617      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0072   |
# |    n_updates        | 549      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 605      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 7600     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.155    |
# |    n_updates        | 649      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.608    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 595      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0774   |
# |    n_updates        | 749      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 576      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 8400     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0599   |
# |    n_updates        | 849      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.569    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 559      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0476   |
# |    n_updates        | 949      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 548      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 9200     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00735  |
# |    n_updates        | 1049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.53     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 540      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 9600     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0652   |
# |    n_updates        | 1149     |
# ----------------------------------
# C:\Users\reply\anaconda3\envs\pytorch_rl\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=-9.00 +/- 9.80
# Episode length: 100.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 100      |
# |    mean_reward      | -9       |
# | rollout/            |          |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    total_timesteps  | 10000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0189   |
# |    n_updates        | 1249     |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 496      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 10000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.49     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 485      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.348    |
# |    n_updates        | 1349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 479      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 10800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.86     |
# |    n_updates        | 1449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 475      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 11200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.399    |
# |    n_updates        | 1549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.432    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 472      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 11600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.4      |
# |    n_updates        | 1649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.412    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 468      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.429    |
# |    n_updates        | 1749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 464      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 12400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.684    |
# |    n_updates        | 1849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 461      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 12800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.52     |
# |    n_updates        | 1949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.353    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 458      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 13200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.193    |
# |    n_updates        | 2049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 455      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 13600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.628    |
# |    n_updates        | 2149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.314    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 451      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 14000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.108    |
# |    n_updates        | 2249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.294    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 447      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 14400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.395    |
# |    n_updates        | 2349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 37.3     |
# |    exploration_rate | 0.275    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 445      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 14800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.485    |
# |    n_updates        | 2449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 36.9     |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 439      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 15200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.63     |
# |    n_updates        | 2549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 36.7     |
# |    exploration_rate | 0.236    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 436      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 15600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.189    |
# |    n_updates        | 2649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 36       |
# |    exploration_rate | 0.216    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 432      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.66     |
# |    n_updates        | 2749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 40.6     |
# |    exploration_rate | 0.196    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 430      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 16400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.315    |
# |    n_updates        | 2849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 38.1     |
# |    exploration_rate | 0.177    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 427      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 16800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.538    |
# |    n_updates        | 2949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 37.1     |
# |    exploration_rate | 0.157    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 424      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 17200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.469    |
# |    n_updates        | 3049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 36.2     |
# |    exploration_rate | 0.138    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 422      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 17600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.512    |
# |    n_updates        | 3149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 42.2     |
# |    exploration_rate | 0.118    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 420      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 18000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.914    |
# |    n_updates        | 3249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 56       |
# |    exploration_rate | 0.0984   |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 418      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 18400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.214    |
# |    n_updates        | 3349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 70.3     |
# |    exploration_rate | 0.0788   |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 416      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 18800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.518    |
# |    n_updates        | 3449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 73       |
# |    exploration_rate | 0.0592   |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 413      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 19200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.131    |
# |    n_updates        | 3549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 79.2     |
# |    exploration_rate | 0.0396   |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 410      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 19600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.468    |
# |    n_updates        | 3649     |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=-14.92 +/- 8.04
# Episode length: 100.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 100      |
# |    mean_reward      | -14.9    |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.584    |
# |    n_updates        | 3749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 90.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 400      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 20000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 397      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 20400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.625    |
# |    n_updates        | 3849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 123      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 395      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 20800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.961    |
# |    n_updates        | 3949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 121      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 393      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 21200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.943    |
# |    n_updates        | 4049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 391      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 21600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.734    |
# |    n_updates        | 4149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 389      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 22000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.828    |
# |    n_updates        | 4249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 387      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 22400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.865    |
# |    n_updates        | 4349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 385      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 22800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.549    |
# |    n_updates        | 4449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 383      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 23200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.691    |
# |    n_updates        | 4549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 383      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 23600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.334    |
# |    n_updates        | 4649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 381      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 24000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.463    |
# |    n_updates        | 4749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 380      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 24400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.137    |
# |    n_updates        | 4849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 379      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 24800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.053    |
# |    n_updates        | 4949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 376      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 25200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.742    |
# |    n_updates        | 5049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 373      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 25600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.314    |
# |    n_updates        | 5149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 373      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 26000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.905    |
# |    n_updates        | 5249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 372      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 26400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.557    |
# |    n_updates        | 5349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 369      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 26800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.557    |
# |    n_updates        | 5449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 368      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 27200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.06     |
# |    n_updates        | 5549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 367      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 27600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.742    |
# |    n_updates        | 5649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 366      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 28000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.808    |
# |    n_updates        | 5749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 366      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 28400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.355    |
# |    n_updates        | 5849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 246      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 365      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 28800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.47     |
# |    n_updates        | 5949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 264      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 364      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 29200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.904    |
# |    n_updates        | 6049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 363      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 29600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.562    |
# |    n_updates        | 6149     |
# ----------------------------------
# Eval num_timesteps=30000, episode_reward=-12.96 +/- 7.49
# Episode length: 100.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 100      |
# |    mean_reward      | -13      |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 30000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.328    |
# |    n_updates        | 6249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 291      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 358      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 30000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 276      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 357      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 30400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.732    |
# |    n_updates        | 6349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 262      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 357      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 30800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.934    |
# |    n_updates        | 6449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 262      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 356      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 31200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.747    |
# |    n_updates        | 6549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 265      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 356      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 31600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.508    |
# |    n_updates        | 6649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 265      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 355      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 32000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.245    |
# |    n_updates        | 6749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 282      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 355      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 32400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.586    |
# |    n_updates        | 6849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 302      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 354      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 32800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 6949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 281      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 354      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 33200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.582    |
# |    n_updates        | 7049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 285      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 353      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 33600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.485    |
# |    n_updates        | 7149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 296      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 352      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 34000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.16     |
# |    n_updates        | 7249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 297      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 352      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 34400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.502    |
# |    n_updates        | 7349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 307      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 351      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 34800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.839    |
# |    n_updates        | 7449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 304      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 350      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 35200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.07     |
# |    n_updates        | 7549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 331      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 350      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 35600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.11     |
# |    n_updates        | 7649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 349      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 36000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.931    |
# |    n_updates        | 7749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 349      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 36400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.629    |
# |    n_updates        | 7849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.02     |
# ...
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 309      |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 88800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.01     |
# |    n_updates        | 20949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 309      |
# |    time_elapsed     | 287      |
# |    total_timesteps  | 89200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.39     |
# |    n_updates        | 21049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 309      |
# |    time_elapsed     | 289      |
# |    total_timesteps  | 89600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0872   |
# |    n_updates        | 21149    |
# ----------------------------------
# Eval num_timesteps=90000, episode_reward=296.04 +/- 604.00
# Episode length: 100.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 100      |
# |    mean_reward      | 296      |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 90000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.62     |
# |    n_updates        | 21249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 308      |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 90000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 309      |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 90400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.36     |
# |    n_updates        | 21349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 309      |
# |    time_elapsed     | 293      |
# |    total_timesteps  | 90800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.785    |
# |    n_updates        | 21449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 267      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 309      |
# |    time_elapsed     | 294      |
# |    total_timesteps  | 91200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.926    |
# |    n_updates        | 21549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 267      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 309      |
# |    time_elapsed     | 296      |
# |    total_timesteps  | 91600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.45     |
# |    n_updates        | 21649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 290      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 309      |
# |    time_elapsed     | 297      |
# |    total_timesteps  | 92000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.86     |
# |    n_updates        | 21749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 295      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 309      |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 92400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.39     |
# |    n_updates        | 21849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 300      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 309      |
# |    time_elapsed     | 299      |
# |    total_timesteps  | 92800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.44     |
# |    n_updates        | 21949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 310      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 309      |
# |    time_elapsed     | 300      |
# |    total_timesteps  | 93200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.19     |
# |    n_updates        | 22049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 294      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 936      |
# |    fps              | 309      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 93600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.549    |
# |    n_updates        | 22149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 302      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 309      |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 94000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.789    |
# |    n_updates        | 22249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 271      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 944      |
# |    fps              | 309      |
# |    time_elapsed     | 304      |
# |    total_timesteps  | 94400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.281    |
# |    n_updates        | 22349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 271      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 948      |
# |    fps              | 309      |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 94800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.155    |
# |    n_updates        | 22449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 952      |
# |    fps              | 309      |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 95200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.69     |
# |    n_updates        | 22549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 309      |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 95600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.986    |
# |    n_updates        | 22649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 309      |
# |    time_elapsed     | 310      |
# |    total_timesteps  | 96000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.3      |
# |    n_updates        | 22749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 964      |
# |    fps              | 309      |
# |    time_elapsed     | 311      |
# |    total_timesteps  | 96400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.42     |
# |    n_updates        | 22849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 252      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 968      |
# |    fps              | 309      |
# |    time_elapsed     | 312      |
# |    total_timesteps  | 96800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.583    |
# |    n_updates        | 22949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 244      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 972      |
# |    fps              | 309      |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 97200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.536    |
# |    n_updates        | 23049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 251      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 976      |
# |    fps              | 309      |
# |    time_elapsed     | 315      |
# |    total_timesteps  | 97600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.332    |
# |    n_updates        | 23149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 249      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 309      |
# |    time_elapsed     | 316      |
# |    total_timesteps  | 98000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.31     |
# |    n_updates        | 23249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 984      |
# |    fps              | 309      |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 98400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.259    |
# |    n_updates        | 23349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 308      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 988      |
# |    fps              | 310      |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 98800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.53     |
# |    n_updates        | 23449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 283      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 992      |
# |    fps              | 310      |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 99200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.03     |
# |    n_updates        | 23549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 288      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 310      |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 99600    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.72     |
# |    n_updates        | 23649    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=-12.86 +/- 7.52
# Episode length: 100.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 100      |
# |    mean_reward      | -12.9    |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 100000   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.41     |
# |    n_updates        | 23749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 279      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 309      |
# |    time_elapsed     | 323      |
# |    total_timesteps  | 100000   |
# ----------------------------------
# Training Complete. Model saved successfully.

# %%
import imageio
from stable_baselines3 import DQN
from gymnasium.wrappers import FlattenObservation
import os

print("--- Starting Cell 4: Evaluation ---")

# --- Delete the frames directory if it exists ---
frames_path = "./evaluation_frames/"
if os.path.exists(frames_path):
    import shutil
    shutil.rmtree(frames_path)
os.makedirs(frames_path, exist_ok=True)
print(f"Cleaned and created directory: {frames_path}")
# --------------------------------------------------------------------

try:
    # Load the trained model
    model_path = './models/dqn_warehouse_final.zip'
    model = DQN.load(model_path)
    print(f"Successfully loaded model from: {model_path}")

    # Create the evaluation environment
    eval_env = WarehouseEnv(render_mode="rgb_array")
    eval_env_wrapped = FlattenObservation(eval_env)
    print("Evaluation environment created and wrapped.")

    output_gif_path = "warehouse_evaluation.gif"
    frames = []

    # Reset the wrapped environment
    obs, info = eval_env_wrapped.reset()
    print("Environment reset. Initial observation received.")

    # Limit the evaluation episode length
    for step in range(200):
        print(f"--- Step {step} ---")

        # Render the ORIGINAL unwrapped environment
        img = eval_env.render()
        if img is not None:
            frames.append(img)
            print(f"Frame {step} rendered and saved.")
        else:
            print(f"Warning: Frame {step} rendering returned None.")


        # Predict the action
        action, _ = model.predict(obs, deterministic=True)
        print(f"Action predicted: {action}")

        # Step the wrapped environment
        obs, reward, terminated, truncated, info = eval_env_wrapped.step(action)
        print(f"Environment stepped. Reward: {reward:.2f}, Terminated: {terminated}, Truncated: {truncated}")

        # The episode ends if done (terminated) or truncated is True
        if terminated or truncated:
            print(f"Episode finished at step {step}. Reason: Terminated={terminated}, Truncated={truncated}")
            # Add a final frame to show the end state
            img = eval_env.render()
            frames.append(img)
            break

    eval_env_wrapped.close()
    print("\n--- Loop Finished ---")

    # Check if frames were captured before saving
    if frames:
        print(f"Saving {len(frames)} frames to {output_gif_path}...")
        imageio.mimsave(output_gif_path, frames, fps=10)
        print("Evaluation GIF saved successfully.")
    else:
        print("Warning: No frames were captured, so no GIF was created.")

except Exception as e:
    print("\n--- AN ERROR OCCURRED ---")
    import traceback
    traceback.print_exc()
# Out:
# --- Starting Cell 4: Evaluation ---
# Cleaned and created directory: ./evaluation_frames/
# Successfully loaded model from: ./models/dqn_warehouse_final.zip
# Evaluation environment created and wrapped.
# Environment reset. Initial observation received.
# --- Step 0 ---
# Frame 0 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.01, Terminated: False, Truncated: False
# --- Step 1 ---
# Frame 1 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.01, Terminated: False, Truncated: False
# --- Step 2 ---
# Frame 2 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.01, Terminated: False, Truncated: False
# --- Step 3 ---
# Frame 3 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.01, Terminated: False, Truncated: False
# --- Step 4 ---
# Frame 4 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 5 ---
# Frame 5 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 6 ---
# Frame 6 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 7 ---
# Frame 7 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 8 ---
# Frame 8 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 9 ---
# Frame 9 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 10 ---
# Frame 10 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 11 ---
# Frame 11 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 12 ---
# Frame 12 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 13 ---
# Frame 13 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 14 ---
# Frame 14 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 15 ---
# Frame 15 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 16 ---
# Frame 16 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 17 ---
# Frame 17 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 18 ---
# Frame 18 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 19 ---
# Frame 19 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 20 ---
# Frame 20 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 21 ---
# Frame 21 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 22 ---
# Frame 22 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 23 ---
# Frame 23 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 24 ---
# Frame 24 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 25 ---
# Frame 25 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 26 ---
# Frame 26 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 27 ---
# Frame 27 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 28 ---
# Frame 28 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 29 ---
# Frame 29 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 30 ---
# Frame 30 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 31 ---
# Frame 31 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 32 ---
# Frame 32 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 33 ---
# Frame 33 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 34 ---
# Frame 34 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 35 ---
# Frame 35 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 36 ---
# Frame 36 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 37 ---
# Frame 37 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 38 ---
# Frame 38 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 39 ---
# Frame 39 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 40 ---
# Frame 40 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 41 ---
# Frame 41 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 42 ---
# Frame 42 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 43 ---
# Frame 43 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 44 ---
# Frame 44 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 45 ---
# Frame 45 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 46 ---
# Frame 46 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 47 ---
# Frame 47 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 48 ---
# Frame 48 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 49 ---
# Frame 49 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 50 ---
# Frame 50 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 51 ---
# Frame 51 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 52 ---
# Frame 52 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 53 ---
# Frame 53 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 54 ---
# Frame 54 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 55 ---
# Frame 55 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 56 ---
# Frame 56 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 57 ---
# Frame 57 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 58 ---
# Frame 58 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 59 ---
# Frame 59 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 60 ---
# Frame 60 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 61 ---
# Frame 61 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 62 ---
# Frame 62 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 63 ---
# Frame 63 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 64 ---
# Frame 64 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 65 ---
# Frame 65 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 66 ---
# Frame 66 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 67 ---
# Frame 67 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 68 ---
# Frame 68 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 69 ---
# Frame 69 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 70 ---
# Frame 70 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 71 ---
# Frame 71 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 72 ---
# Frame 72 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 73 ---
# Frame 73 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 74 ---
# Frame 74 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 75 ---
# Frame 75 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 76 ---
# Frame 76 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 77 ---
# Frame 77 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 78 ---
# Frame 78 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 79 ---
# Frame 79 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 80 ---
# Frame 80 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 81 ---
# Frame 81 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 82 ---
# Frame 82 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 83 ---
# Frame 83 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 84 ---
# Frame 84 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 85 ---
# Frame 85 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 86 ---
# Frame 86 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 87 ---
# Frame 87 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 88 ---
# Frame 88 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 89 ---
# Frame 89 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 90 ---
# Frame 90 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 91 ---
# Frame 91 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 92 ---
# Frame 92 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 93 ---
# Frame 93 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 94 ---
# Frame 94 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 95 ---
# Frame 95 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 96 ---
# Frame 96 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 97 ---
# Frame 97 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 98 ---
# Frame 98 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: False, Truncated: False
# --- Step 99 ---
# Frame 99 rendered and saved.
# Action predicted: 1
# Environment stepped. Reward: -0.11, Terminated: True, Truncated: False
# Episode finished at step 99. Reason: Terminated=True, Truncated=False
#
# --- Loop Finished ---
# Saving 101 frames to warehouse_evaluation.gif...
# Evaluation GIF saved successfully.

# %%
import os
import imageio
import re

input_folder = "./animation_frames/"
output_gif_path = "warehouse_training.gif"
fps = 2

try:
    image_files = [f for f in os.listdir(input_folder) if f.endswith('.png')]

    def sort_key(filename):
        match = re.search(r'(\d+)', filename)
        return int(match.group(1)) if match else 0

    image_files.sort(key=sort_key)

    if not image_files:
        print(f"Error: No image files found in '{input_folder}'. Cannot create GIF.")
    else:
        print(f"Found {len(image_files)} frames to animate.")

        frames = []
        for filename in image_files:
            file_path = os.path.join(input_folder, filename)
            frames.append(imageio.imread(file_path))

        print(f"Saving GIF to '{output_gif_path}'...")
        imageio.mimsave(output_gif_path, frames, fps=fps, loop=0)
        print("--- GIF created successfully! ---")


except FileNotFoundError:
    print(f"Error: The directory '{input_folder}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Found 20 frames to animate.
# C:\Users\reply\AppData\Local\Temp\ipykernel_6524\2766477093.py:26: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   frames.append(imageio.imread(file_path))
# Saving GIF to 'warehouse_training.gif'...
# --- GIF created successfully! ---

# %%
pip install imageio[pyav]
# Out:
# Requirement already satisfied: imageio[pyav] in c:\users\reply\anaconda3\envs\pytorch_rl\lib\site-packages (2.37.0)
# Requirement already satisfied: numpy in c:\users\reply\anaconda3\envs\pytorch_rl\lib\site-packages (from imageio[pyav]) (2.1.3)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\reply\anaconda3\envs\pytorch_rl\lib\site-packages (from imageio[pyav]) (11.1.0)
# Requirement already satisfied: av in c:\users\reply\anaconda3\envs\pytorch_rl\lib\site-packages (from imageio[pyav]) (14.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import imageio.v3 as iio
import os

# --- Configuration ---
gif_path = "warehouse_training.gif"
mp4_path = "warehouse_training.mp4"
fps = 2 

print(f"--- Converting {gif_path} to {mp4_path} ---")

if not os.path.exists(gif_path):
    print(f"Error: The file '{gif_path}' was not found. Please ensure it is in the correct directory.")
else:
    try:
        print("Reading frames from GIF...")
        
        # Read all frames from the GIF into a list in memory.
        # index=None tells it to read all frames. This is a robust way to handle it.
        frames = iio.imread(gif_path, index=None)
        
        num_frames = len(frames)
        print(f"Successfully read {num_frames} frames.")

        print(f"Writing {num_frames} frames to MP4 with {fps} FPS...")
        
        # Write the list of frames to the new MP4 video file.
        iio.imwrite(mp4_path, frames, fps=fps, codec='libx264')

        print("--- Conversion successful! ---")

    except Exception as e:
        import traceback
        print(f"\nAn error occurred during conversion:")
        traceback.print_exc()
# Out:
# --- Converting warehouse_training.gif to warehouse_training.mp4 ---
# Reading frames from GIF...
# Successfully read 20 frames.
# Writing 20 frames to MP4 with 2 FPS...
# --- Conversion successful! ---
# You can now find 'warehouse_training.mp4' in your file browser and upload it to LinkedIn.
